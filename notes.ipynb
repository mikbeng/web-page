# %% [markdown]
# ## Todo:
# - Tjänster/kompetenser:
#     - Embedded/mjukvara: Lägg till target processorer du jobbat mkt med esp32, stm32, nrf52 etc. Även devops, gitlab
#     - Elektronikutveckling: Kicad, altium, onshape/fusion360..
#     - Lägg till prototyputveckling/produktutveckling? Typ CAD 3d print etc?
# -

# %% [markdown]
# Låt oss uppdatera de övriga tjänsterna mjukvaruutveckling, test och automation samt certifieringe och standardisering.
#
# Lite som jag tänker vi kan ha med (men inte begränsad till):
#
# Mjukvaruutveckling:
# - Mjukvara för inbyggda system (C/C++) samt autormation (Python)
# - få med lite kring viilka processorarkitektur jag har erfarenhet av: esp32, nrf, stm32 (ARM cortex)
# - jobbat med devops/git
# - CAN/CANopen
# -
#
# Test och automation
# - Kan hjälpa till med automationsutrystning för produktion
# - Framtagning av testfixturer för PCB för serieproduktion
#
# Mätning och Certifiering (döp om till detta)
# - Felsökning och design för EMC
# - Har erfarenhet av safety standarder (CE) för produktutveckling (omformulera?)
# - kanske nått mer
