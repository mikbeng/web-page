# %% [markdown]
# ## Todo:
# - erfaranheter:
#     - Headings: Pluspole AB \n Embedded developer (med lite mindre font?)
#     - Ändra blå färg? Kanske ha en och samma "tema" färg för hela hemsidan (färg på logo etc.) Orange?
#     - Se om det går att trycka ihop tidslinjen lite
#     - Lägg till konsult engcon/knowit överst.
#     - Lägg till bilder på företagen
